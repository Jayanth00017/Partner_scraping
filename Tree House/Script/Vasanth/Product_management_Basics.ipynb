# %%
import pandas as pd
from bs4 import BeautifulSoup
from bs4.element import Comment
import requests
import urllib.request
import cssutils
import re
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import time

# %%
pd.set_option("display.max_columns", 156)

# %%
driver=webdriver.Chrome(r"C:\ProgramData\chocolatey\bin\chromedriver")

# %%
op_df=pd.DataFrame(pd.read_csv("output.csv"))

# %%
op_df
# Out:
# Empty DataFrame
# Columns: [title, learn_type, topics, skills, description, cover_image, cover_video, embedded_video_url, delivery_method, instruction_type, content, what_will_learn, prerequisites, target_students, instructor|1|name, instructor|1|designation, instructor|1|instructor_bio, instructor|1|linkedin_url, instructor|1|facebook_url, instructor|1|twitter_url, instructor|1|instructor_image, instructor|2|name, instructor|2|designation, instructor|2|instructor_bio, instructor|2|linkedin_url, instructor|2|facebook_url, instructor|2|twitter_url, instructor|2|instructor_image, instructor|3|name, instructor|3|designation, instructor|3|instructor_bio, instructor|3|linkedin_url, instructor|3|facebook_url, instructor|3|twitter_url, instructor|3|instructor_image, instructor|4|name, instructor|4|designation, instructor|4|instructor_bio, instructor|4|linkedin_url, instructor|4|facebook_url, instructor|4|twitter_url, instructor|4|instructor_image, instructor|5|name, instructor|5|designation, instructor|5|instructor_bio, instructor|5|linkedin_url, instructor|5|facebook_url, instructor|5|twitter_url, instructor|5|instructor_image, review|1|reviewer_name, review|1|photo, review|1|review_date, review|1|review, review|1|rating, review|2|reviewer_name, review|2|photo, review|2|review_date, review|2|review, review|2|rating, review|3|reviewer_name, review|3|photo, review|3|review_date, review|3|review, review|3|rating, review|4|reviewer_name, review|4|photo, review|4|review_date, review|4|review, review|5|reviewer_name, review|5|photo, review|5|review_date, review|5|review, review|5|rating, review|5|rating.1, total_duration, total_duration_unit, total_video_content, total_video_content_unit, recommended_effort_per_week, avg_session_duration_with_instructor, batch|1|batch_size, batch|1|batch_start_date, batch|1|batch_end_date, batch|2|batch_size, batch|2|batch_start_date, batch|2|batch_end_date, enrollment_start_date, enrollment_end_date, level, languages, short_description, subtitle_languages, accessibilities, availabilities, Display Price, pricing_type, currency, regular_price, sale_price, additional_pricing_details, ...]
# Index: []

# %%
urls=["https://teamtreehouse.com/library/introduction-to-product-design","https://teamtreehouse.com/library/scrum-basics","https://teamtreehouse.com/library/introducing-coda","https://teamtreehouse.com/library/learning-with-coda","https://teamtreehouse.com/library/hello-ux","https://teamtreehouse.com/library/intro-to-design-thinking","https://teamtreehouse.com/library/conducting-user-interviews","https://teamtreehouse.com/library/data-analysis-basics","https://teamtreehouse.com/library/spreadsheet-basics","https://teamtreehouse.com/library/web-accessibility-compliance","https://teamtreehouse.com/library/data-visualization-with-excel","https://teamtreehouse.com/library/soft-skills","https://teamtreehouse.com/library/presentation-skills-2"]

# %%
len(urls)
# Out:
# 13

# %%
html_content=[]
soup=[]

for i in range (len(urls)):
    html_content.append(requests.get(urls[i]).text)
    soup.append(BeautifulSoup(html_content[i], "lxml"))

# %%
title=[]
for i in soup:
    title.append(i.title.text)
op_df["title"]=title

# %%
description=[]
for i in soup:
    try:
        pt=(i.find(class_="grid-66 tablet-grid-60").find_all("p"))
        description.append(pt[1])
    except:
        print("Error")
op_df["description"]=description

# %%
inst_1_name=[]
for i in soup:
    try:
        inst_1_name.append(i.find("div",{"id" : "syllabus-authors"}).find("h4").text)
    except:
        inst_1_name.append(i.find("div",{"id" : "workshop-authors"}).find("h4").text)
op_df["instructor|1|name"]=inst_1_name

# %%
inst_bio=[]
for i in soup:
    inst_bio.append(i.find(class_="grid-33 tablet-grid-40").find("p").text)
op_df["instructor|1|instructor_bio"]=inst_bio

# %%
inst_desig=[]
for i in soup:
    inst_desig.append("Teacher")
op_df["instructor|1|designation"]=inst_desig

# %%
inst_img=[]
for i in soup:
    prt=(i.find(class_="instructor-avatar")["style"].split("("))
    inst_img.append(prt[1].replace(")",""))
op_df["instructor|1|instructor_image"]=inst_img

# %%
level=[]
for i in soup:
    try:
        level.append(i.find("li",{"id" : "syllabus-skill-level"}).text)
    except:
        level.append(i.find("li",{"id" : "workshop-skill-level"}).text)
op_df["level"]=level

# %%
topics=[]
for i in soup:
        topics.append(i.find("ul",class_="tags actions").find("a").text)
op_df["topics"]=topics

# %%
op_df["partner_course_url"]=urls

# %%
what_will_learn=[]
for i in soup:
    try:
        what_will_learn.append(i.find(class_="check-list").text.replace("\n","|"))
        
    except:
        what_will_learn.append(i.find(class_="check-list"))
op_df["what_will_learn"]=what_will_learn

# %%
learn_type=[]
for i in soup:
    if(i.text.find("Workshop"))>=1:
        learn_type.append("Workshop")
    else:
        learn_type.append("Course")
op_df["learn_type"]=learn_type

# %%
duration=[]
duration_unit=[]
for i in soup:
    try:
        pt=(i.find("div",{"id" : "syllabus-title"}).find("h2").text.replace("\n","").split(" "))
        pt=(pt[4].split("-"))
        duration.append(pt[0])
        duration_unit.append(pt[1])
    except:
        pr=(i.find("div",{"id" : "workshop-title"}).find("h2").text.replace("\n","").split(" "))
        pr=(pr[4].split("-"))
        duration.append(pr[0])
        duration_unit.append(pr[1])
                
op_df["total_duration"]=duration
op_df["total_duration_unit"]=duration_unit

# %%
lang=[]
for i in soup:
    lang.append("English")
op_df["languages"]=lang
op_df["subtitle_languages"]=lang

# %%
inst_type=[]
for i in soup:
    inst_type.append("Self Paced")
op_df["instruction_type"]=inst_type

# %%
available=[]
for i in soup:
    available.append("Downloadable Content")
op_df["availabilities"]=available

# %%
content=[]
for i in urls:
    tempro=[]
    driver.get(i)
    time.sleep(5)
    a=driver.find_elements_by_class_name("toggle-steps")
    for i in a:
        time.sleep(2)
        try:
            i.click()
        except:
            pass
    pri=(driver.find_elements_by_class_name("stage-meta"))
    for j in pri:
        prnt=(j.text.replace(":","").replace("questions","").replace("\n","|"))
        res = ''.join([i for i in prnt if not i.isdigit()])
        tempro.append(res)
    content.append(tempro)



op_df["content"]=content

# %%
op_df #17 Kpis
# Out:
#                                                 title learn_type  \
# 0   Introduction to Product Design Course (How To)...     Course
# 1            Scrum Basics Course (How To) | Treehouse     Course
# 2               Introducing Coda (How To) | Treehouse   Workshop
# 3             Learning with Coda (How To) | Treehouse   Workshop
# 4                       Hello UX (How To) | Treehouse   Workshop
# 5   Intro to Design Thinking Course (How To) | Tre...     Course
# 6   Conducting User Interviews Course (How To) | T...     Course
# 7    Data Analysis Basics Course (How To) | Treehouse     Course
# 8      Spreadsheet Basics Course (How To) | Treehouse     Course
# 9   Web Accessibility Compliance Course (How To) |...     Course
# 10  Data Visualization with Excel Course (How To) ...     Course
# 11            Soft Skills Course (How To) | Treehouse     Course
# 12    Presentation Skills Course (How To) | Treehouse     Course
#
#                topics skills  \
# 0              Design    NaN
# 1   Development Tools    NaN
# 2   Development Tools    NaN
# 3   Development Tools    NaN
# 4              Design    NaN
# 5              Design    NaN
# 6              Design    NaN
# 7       Data Analysis    NaN
# 8       Data Analysis    NaN
# 9   Development Tools    NaN
# 10      Data Analysis    NaN
# 11           Business    NaN
# 12           Business    NaN
#
#                                           description cover_image cover_video  \
# 0   [Over the last 10 years, design has proven to ...         NaN         NaN
# 1   [These days, just about every software team sa...         NaN         NaN
# 2   [Get started with the basics of Coda! Coda rei...         NaN         NaN
# 3   [In this workshop, you'll learn how to use Cod...         NaN         NaN
# 4   [User Experience Design, commonly called UX De...         NaN         NaN
# 5   [Learn the user-centered methods and mindsets ...         NaN         NaN
# 6   [Learn how to validate product ideas by identi...         NaN         NaN
# 7   [Learn how to make better decisions with data ...         NaN         NaN
# 8   [A spreadsheet is an electronic document that ...         NaN         NaN
# 9   [Your content is clear, your images are respon...         NaN         NaN
# 10  [This overview of Data Visualization in Excel ...         NaN         NaN
# 11  [In this series of videos, we're going to expl...         NaN         NaN
# 12  [Learn techniques for delivering effective pre...         NaN         NaN
#
#    embedded_video_url delivery_method instruction_type  \
# 0                 NaN             NaN       Self Paced
# 1                 NaN             NaN       Self Paced
# 2                 NaN             NaN       Self Paced
# 3                 NaN             NaN       Self Paced
# 4                 NaN             NaN       Self Paced
# 5                 NaN             NaN       Self Paced
# 6                 NaN             NaN       Self Paced
# 7                 NaN             NaN       Self Paced
# 8                 NaN             NaN       Self Paced
# 9                 NaN             NaN       Self Paced
# 10                NaN             NaN       Self Paced
# 11                NaN             NaN       Self Paced
# 12                NaN             NaN       Self Paced
#
#                                               content  \
# 0   [What is Product Design?|The definition of a P...
# 1   [What is Agile?|Learn about the Agile Manifest...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [Becoming a Design Thinker|Before you can lear...
# 6   [Recruiting Participants|Learn why interviews ...
# 7   [Introducing Data Analysis|From the daily weat...
# 8   [Introducing Spreadsheets|What are spreadsheet...
# 9   [Access for Everybody|Welcome to Web Accessibi...
# 10  [Introduction To Data Visualization|Learn why ...
# 11  [Important Skills For Professional Success|No ...
# 12  [Preparing to Present|In this stage, we'll lea...
#
#                                       what_will_learn prerequisites  \
# 0   |Understand “What is Product Design” (high lev...           NaN
# 1   |Agile  |What is Scrum?  |Roles in Scrum  |Spr...           NaN
# 2                                                None           NaN
# 3                                                None           NaN
# 4   |Define User Experience design|Describe the qu...           NaN
# 5   |Define design thinking |Understand who is you...           NaN
# 6                                                None           NaN
# 7   |Cleaning and preparing data in spreadsheets|S...           NaN
# 8   |Spreadsheet concepts and vocabulary|Importing...           NaN
# 9   |Accessibility at a Glance  |NonVisual Desktop...           NaN
# 10  |Data visualization fundamentals|Excel chart c...           NaN
# 11                                               None           NaN
# 12  |Identifying an end goal and audience|Creating...           NaN
#
#    target_students     instructor|1|name instructor|1|designation  \
# 0              NaN               May Kim                  Teacher
# 1              NaN  Matt Anthes-Washburn                  Teacher
# 2              NaN        Guil Hernandez                  Teacher
# 3              NaN        Guil Hernandez                  Teacher
# 4              NaN        Anwar Montasir                  Teacher
# 5              NaN         Devin O'Bryan                  Teacher
# 6              NaN          Tomer Sharon                  Teacher
# 7              NaN            Ben Deitch                  Teacher
# 8              NaN        Michael Watson                  Teacher
# 9              NaN           Aisha Blake                  Teacher
# 10             NaN        Michael Watson                  Teacher
# 11             NaN           Dan Gorgone                  Teacher
# 12             NaN           Julie Menge                  Teacher
#
#                           instructor|1|instructor_bio  \
# 0   May has been working as an in-house designer f...
# 1   Matt Anthes-Washburn is a Product Owner and in...
# 2   Guil is a Full Stack JavaScript and Front End ...
# 3   Guil is a Full Stack JavaScript and Front End ...
# 4   Anwar Montasir is a UX Design, Front End Web D...
# 5   Devin O’Bryan is Creative Director for Project...
# 6   Tomer Sharon is a Senior User Experience Resea...
# 7   Ben is an Android teacher at Treehouse with a ...
# 8   Michael Watson is the CFO & COO of Treehouse. ...
# 9   Aisha Blake arrived in Detroit in 2013 to serv...
# 10  Michael Watson is the CFO & COO of Treehouse. ...
# 11  Dan is an online learning course creator with ...
# 12  Julie is a Human Resources Generalist. She is ...
#
#    instructor|1|linkedin_url instructor|1|facebook_url  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                        NaN                       NaN
# 8                        NaN                       NaN
# 9                        NaN                       NaN
# 10                       NaN                       NaN
# 11                       NaN                       NaN
# 12                       NaN                       NaN
#
#    instructor|1|twitter_url  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
#
#                         instructor|1|instructor_image instructor|2|name  \
# 0   'https://secure.gravatar.com/avatar/f5298524cc...               NaN
# 1   'https://uploads.teamtreehouse.com/production/...               NaN
# 2   'https://secure.gravatar.com/avatar/bad4b01a17...               NaN
# 3   'https://secure.gravatar.com/avatar/bad4b01a17...               NaN
# 4   'https://uploads.teamtreehouse.com/production/...               NaN
# 5   'https://secure.gravatar.com/avatar/98ebe89613...               NaN
# 6   'https://secure.gravatar.com/avatar/21bb0d7d01...               NaN
# 7   'https://secure.gravatar.com/avatar/d74a55f8bc...               NaN
# 8   'https://secure.gravatar.com/avatar/bdcd7b6fdb...               NaN
# 9   'https://uploads.teamtreehouse.com/production/...               NaN
# 10  'https://secure.gravatar.com/avatar/bdcd7b6fdb...               NaN
# 11  'https://uploads.teamtreehouse.com/production/...               NaN
# 12  'https://uploads.teamtreehouse.com/production/...               NaN
#
#    instructor|2|designation instructor|2|instructor_bio  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# 5                       NaN                         NaN
# 6                       NaN                         NaN
# 7                       NaN                         NaN
# 8                       NaN                         NaN
# 9                       NaN                         NaN
# 10                      NaN                         NaN
# 11                      NaN                         NaN
# 12                      NaN                         NaN
#
#    instructor|2|linkedin_url instructor|2|facebook_url  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                        NaN                       NaN
# 8                        NaN                       NaN
# 9                        NaN                       NaN
# 10                       NaN                       NaN
# 11                       NaN                       NaN
# 12                       NaN                       NaN
#
#    instructor|2|twitter_url instructor|2|instructor_image instructor|3|name  \
# 0                       NaN                           NaN               NaN
# 1                       NaN                           NaN               NaN
# 2                       NaN                           NaN               NaN
# 3                       NaN                           NaN               NaN
# 4                       NaN                           NaN               NaN
# 5                       NaN                           NaN               NaN
# 6                       NaN                           NaN               NaN
# 7                       NaN                           NaN               NaN
# 8                       NaN                           NaN               NaN
# 9                       NaN                           NaN               NaN
# 10                      NaN                           NaN               NaN
# 11                      NaN                           NaN               NaN
# 12                      NaN                           NaN               NaN
#
#    instructor|3|designation instructor|3|instructor_bio  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# 5                       NaN                         NaN
# 6                       NaN                         NaN
# 7                       NaN                         NaN
# 8                       NaN                         NaN
# 9                       NaN                         NaN
# 10                      NaN                         NaN
# 11                      NaN                         NaN
# 12                      NaN                         NaN
#
#    instructor|3|linkedin_url instructor|3|facebook_url  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                        NaN                       NaN
# 8                        NaN                       NaN
# 9                        NaN                       NaN
# 10                       NaN                       NaN
# 11                       NaN                       NaN
# 12                       NaN                       NaN
#
#    instructor|3|twitter_url instructor|3|instructor_image instructor|4|name  \
# 0                       NaN                           NaN               NaN
# 1                       NaN                           NaN               NaN
# 2                       NaN                           NaN               NaN
# 3                       NaN                           NaN               NaN
# 4                       NaN                           NaN               NaN
# 5                       NaN                           NaN               NaN
# 6                       NaN                           NaN               NaN
# 7                       NaN                           NaN               NaN
# 8                       NaN                           NaN               NaN
# 9                       NaN                           NaN               NaN
# 10                      NaN                           NaN               NaN
# 11                      NaN                           NaN               NaN
# 12                      NaN                           NaN               NaN
#
#    instructor|4|designation instructor|4|instructor_bio  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# 5                       NaN                         NaN
# 6                       NaN                         NaN
# 7                       NaN                         NaN
# 8                       NaN                         NaN
# 9                       NaN                         NaN
# 10                      NaN                         NaN
# 11                      NaN                         NaN
# 12                      NaN                         NaN
#
#    instructor|4|linkedin_url instructor|4|facebook_url  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                        NaN                       NaN
# 8                        NaN                       NaN
# 9                        NaN                       NaN
# 10                       NaN                       NaN
# 11                       NaN                       NaN
# 12                       NaN                       NaN
#
#    instructor|4|twitter_url instructor|4|instructor_image instructor|5|name  \
# 0                       NaN                           NaN               NaN
# 1                       NaN                           NaN               NaN
# 2                       NaN                           NaN               NaN
# 3                       NaN                           NaN               NaN
# 4                       NaN                           NaN               NaN
# 5                       NaN                           NaN               NaN
# 6                       NaN                           NaN               NaN
# 7                       NaN                           NaN               NaN
# 8                       NaN                           NaN               NaN
# 9                       NaN                           NaN               NaN
# 10                      NaN                           NaN               NaN
# 11                      NaN                           NaN               NaN
# 12                      NaN                           NaN               NaN
#
#    instructor|5|designation instructor|5|instructor_bio  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# 5                       NaN                         NaN
# 6                       NaN                         NaN
# 7                       NaN                         NaN
# 8                       NaN                         NaN
# 9                       NaN                         NaN
# 10                      NaN                         NaN
# 11                      NaN                         NaN
# 12                      NaN                         NaN
#
#    instructor|5|linkedin_url instructor|5|facebook_url  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                        NaN                       NaN
# 8                        NaN                       NaN
# 9                        NaN                       NaN
# 10                       NaN                       NaN
# 11                       NaN                       NaN
# 12                       NaN                       NaN
#
#    instructor|5|twitter_url instructor|5|instructor_image  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
# 5                       NaN                           NaN
# 6                       NaN                           NaN
# 7                       NaN                           NaN
# 8                       NaN                           NaN
# 9                       NaN                           NaN
# 10                      NaN                           NaN
# 11                      NaN                           NaN
# 12                      NaN                           NaN
#
#    review|1|reviewer_name review|1|photo review|1|review_date review|1|review  \
# 0                     NaN            NaN                  NaN             NaN
# 1                     NaN            NaN                  NaN             NaN
# 2                     NaN            NaN                  NaN             NaN
# 3                     NaN            NaN                  NaN             NaN
# 4                     NaN            NaN                  NaN             NaN
# 5                     NaN            NaN                  NaN             NaN
# 6                     NaN            NaN                  NaN             NaN
# 7                     NaN            NaN                  NaN             NaN
# 8                     NaN            NaN                  NaN             NaN
# 9                     NaN            NaN                  NaN             NaN
# 10                    NaN            NaN                  NaN             NaN
# 11                    NaN            NaN                  NaN             NaN
# 12                    NaN            NaN                  NaN             NaN
#
#    review|1|rating review|2|reviewer_name review|2|photo review|2|review_date  \
# 0              NaN                    NaN            NaN                  NaN
# 1              NaN                    NaN            NaN                  NaN
# 2              NaN                    NaN            NaN                  NaN
# 3              NaN                    NaN            NaN                  NaN
# 4              NaN                    NaN            NaN                  NaN
# 5              NaN                    NaN            NaN                  NaN
# 6              NaN                    NaN            NaN                  NaN
# 7              NaN                    NaN            NaN                  NaN
# 8              NaN                    NaN            NaN                  NaN
# 9              NaN                    NaN            NaN                  NaN
# 10             NaN                    NaN            NaN                  NaN
# 11             NaN                    NaN            NaN                  NaN
# 12             NaN                    NaN            NaN                  NaN
#
#    review|2|review review|2|rating review|3|reviewer_name review|3|photo  \
# 0              NaN             NaN                    NaN            NaN
# 1              NaN             NaN                    NaN            NaN
# 2              NaN             NaN                    NaN            NaN
# 3              NaN             NaN                    NaN            NaN
# 4              NaN             NaN                    NaN            NaN
# 5              NaN             NaN                    NaN            NaN
# 6              NaN             NaN                    NaN            NaN
# 7              NaN             NaN                    NaN            NaN
# 8              NaN             NaN                    NaN            NaN
# 9              NaN             NaN                    NaN            NaN
# 10             NaN             NaN                    NaN            NaN
# 11             NaN             NaN                    NaN            NaN
# 12             NaN             NaN                    NaN            NaN
#
#    review|3|review_date review|3|review review|3|rating  \
# 0                   NaN             NaN             NaN
# 1                   NaN             NaN             NaN
# 2                   NaN             NaN             NaN
# 3                   NaN             NaN             NaN
# 4                   NaN             NaN             NaN
# 5                   NaN             NaN             NaN
# 6                   NaN             NaN             NaN
# 7                   NaN             NaN             NaN
# 8                   NaN             NaN             NaN
# 9                   NaN             NaN             NaN
# 10                  NaN             NaN             NaN
# 11                  NaN             NaN             NaN
# 12                  NaN             NaN             NaN
#
#    review|4|reviewer_name review|4|photo review|4|review_date review|4|review  \
# 0                     NaN            NaN                  NaN             NaN
# 1                     NaN            NaN                  NaN             NaN
# 2                     NaN            NaN                  NaN             NaN
# 3                     NaN            NaN                  NaN             NaN
# 4                     NaN            NaN                  NaN             NaN
# 5                     NaN            NaN                  NaN             NaN
# 6                     NaN            NaN                  NaN             NaN
# 7                     NaN            NaN                  NaN             NaN
# 8                     NaN            NaN                  NaN             NaN
# 9                     NaN            NaN                  NaN             NaN
# 10                    NaN            NaN                  NaN             NaN
# 11                    NaN            NaN                  NaN             NaN
# 12                    NaN            NaN                  NaN             NaN
#
#    review|5|reviewer_name review|5|photo review|5|review_date review|5|review  \
# 0                     NaN            NaN                  NaN             NaN
# 1                     NaN            NaN                  NaN             NaN
# 2                     NaN            NaN                  NaN             NaN
# 3                     NaN            NaN                  NaN             NaN
# 4                     NaN            NaN                  NaN             NaN
# 5                     NaN            NaN                  NaN             NaN
# 6                     NaN            NaN                  NaN             NaN
# 7                     NaN            NaN                  NaN             NaN
# 8                     NaN            NaN                  NaN             NaN
# 9                     NaN            NaN                  NaN             NaN
# 10                    NaN            NaN                  NaN             NaN
# 11                    NaN            NaN                  NaN             NaN
# 12                    NaN            NaN                  NaN             NaN
#
#    review|5|rating review|5|rating.1 total_duration total_duration_unit  \
# 0              NaN               NaN             56              minute
# 1              NaN               NaN            107              minute
# 2              NaN               NaN             32              minute
# 3              NaN               NaN             24              minute
# 4              NaN               NaN             21              minute
# 5              NaN               NaN             75              minute
# 6              NaN               NaN             42              minute
# 7              NaN               NaN             75              minute
# 8              NaN               NaN            138              minute
# 9              NaN               NaN            124              minute
# 10             NaN               NaN             90              minute
# 11             NaN               NaN            212              minute
# 12             NaN               NaN             43              minute
#
#    total_video_content total_video_content_unit recommended_effort_per_week  \
# 0                  NaN                      NaN                         NaN
# 1                  NaN                      NaN                         NaN
# 2                  NaN                      NaN                         NaN
# 3                  NaN                      NaN                         NaN
# 4                  NaN                      NaN                         NaN
# 5                  NaN                      NaN                         NaN
# 6                  NaN                      NaN                         NaN
# 7                  NaN                      NaN                         NaN
# 8                  NaN                      NaN                         NaN
# 9                  NaN                      NaN                         NaN
# 10                 NaN                      NaN                         NaN
# 11                 NaN                      NaN                         NaN
# 12                 NaN                      NaN                         NaN
#
#    avg_session_duration_with_instructor batch|1|batch_size  \
# 0                                   NaN                NaN
# 1                                   NaN                NaN
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                                   NaN                NaN
# 5                                   NaN                NaN
# 6                                   NaN                NaN
# 7                                   NaN                NaN
# 8                                   NaN                NaN
# 9                                   NaN                NaN
# 10                                  NaN                NaN
# 11                                  NaN                NaN
# 12                                  NaN                NaN
#
#    batch|1|batch_start_date batch|1|batch_end_date batch|2|batch_size  \
# 0                       NaN                    NaN                NaN
# 1                       NaN                    NaN                NaN
# 2                       NaN                    NaN                NaN
# 3                       NaN                    NaN                NaN
# 4                       NaN                    NaN                NaN
# 5                       NaN                    NaN                NaN
# 6                       NaN                    NaN                NaN
# 7                       NaN                    NaN                NaN
# 8                       NaN                    NaN                NaN
# 9                       NaN                    NaN                NaN
# 10                      NaN                    NaN                NaN
# 11                      NaN                    NaN                NaN
# 12                      NaN                    NaN                NaN
#
#    batch|2|batch_start_date batch|2|batch_end_date enrollment_start_date  \
# 0                       NaN                    NaN                   NaN
# 1                       NaN                    NaN                   NaN
# 2                       NaN                    NaN                   NaN
# 3                       NaN                    NaN                   NaN
# 4                       NaN                    NaN                   NaN
# 5                       NaN                    NaN                   NaN
# 6                       NaN                    NaN                   NaN
# 7                       NaN                    NaN                   NaN
# 8                       NaN                    NaN                   NaN
# 9                       NaN                    NaN                   NaN
# 10                      NaN                    NaN                   NaN
# 11                      NaN                    NaN                   NaN
# 12                      NaN                    NaN                   NaN
#
#    enrollment_end_date         level languages short_description  \
# 0                  NaN  Intermediate   English               NaN
# 1                  NaN  Intermediate   English               NaN
# 2                  NaN      Beginner   English               NaN
# 3                  NaN      Beginner   English               NaN
# 4                  NaN      Beginner   English               NaN
# 5                  NaN      Beginner   English               NaN
# 6                  NaN      Beginner   English               NaN
# 7                  NaN      Beginner   English               NaN
# 8                  NaN      Beginner   English               NaN
# 9                  NaN      Beginner   English               NaN
# 10                 NaN      Beginner   English               NaN
# 11                 NaN      Beginner   English               NaN
# 12                 NaN      Beginner   English               NaN
#
#    subtitle_languages accessibilities        availabilities Display Price  \
# 0             English             NaN  Downloadable Content           NaN
# 1             English             NaN  Downloadable Content           NaN
# 2             English             NaN  Downloadable Content           NaN
# 3             English             NaN  Downloadable Content           NaN
# 4             English             NaN  Downloadable Content           NaN
# 5             English             NaN  Downloadable Content           NaN
# 6             English             NaN  Downloadable Content           NaN
# 7             English             NaN  Downloadable Content           NaN
# 8             English             NaN  Downloadable Content           NaN
# 9             English             NaN  Downloadable Content           NaN
# 10            English             NaN  Downloadable Content           NaN
# 11            English             NaN  Downloadable Content           NaN
# 12            English             NaN  Downloadable Content           NaN
#
#    pricing_type currency regular_price sale_price additional_pricing_details  \
# 0           NaN      NaN           NaN        NaN                        NaN
# 1           NaN      NaN           NaN        NaN                        NaN
# 2           NaN      NaN           NaN        NaN                        NaN
# 3           NaN      NaN           NaN        NaN                        NaN
# 4           NaN      NaN           NaN        NaN                        NaN
# 5           NaN      NaN           NaN        NaN                        NaN
# 6           NaN      NaN           NaN        NaN                        NaN
# 7           NaN      NaN           NaN        NaN                        NaN
# 8           NaN      NaN           NaN        NaN                        NaN
# 9           NaN      NaN           NaN        NaN                        NaN
# 10          NaN      NaN           NaN        NaN                        NaN
# 11          NaN      NaN           NaN        NaN                        NaN
# 12          NaN      NaN           NaN        NaN                        NaN
#
#    course_financing_available indian_students_program_fee  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# 5                         NaN                         NaN
# 6                         NaN                         NaN
# 7                         NaN                         NaN
# 8                         NaN                         NaN
# 9                         NaN                         NaN
# 10                        NaN                         NaN
# 11                        NaN                         NaN
# 12                        NaN                         NaN
#
#    indian_students_payment_deadline indian_students_GST_included  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# 5                               NaN                          NaN
# 6                               NaN                          NaN
# 7                               NaN                          NaN
# 8                               NaN                          NaN
# 9                               NaN                          NaN
# 10                              NaN                          NaN
# 11                              NaN                          NaN
# 12                              NaN                          NaN
#
#    indian_student_installments|1|installment_amount  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
#
#    indian_student_installments|1|payment_deadline  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
#
#    indian_student_installments|2|installment_amount  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
#
#    indian_student_installments|2|payment_deadline  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
#
#    international_students_program_fee international_students_payment_deadline  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
# 5                                 NaN                                     NaN
# 6                                 NaN                                     NaN
# 7                                 NaN                                     NaN
# 8                                 NaN                                     NaN
# 9                                 NaN                                     NaN
# 10                                NaN                                     NaN
# 11                                NaN                                     NaN
# 12                                NaN                                     NaN
#
#    international_student_installments|1|installment_amount  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#    international_student_installments|1|payment_deadline  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#    international_student_installments|2|installment_amount  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#    international_student_installments|2|payment_deadline institute  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 12                                                NaN          NaN
#
#                                    partner_course_url  \
# 0   https://teamtreehouse.com/library/introduction...
# 1      https://teamtreehouse.com/library/scrum-basics
# 2   https://teamtreehouse.com/library/introducing-...
# 3   https://teamtreehouse.com/library/learning-wit...
# 4          https://teamtreehouse.com/library/hello-ux
# 5   https://teamtreehouse.com/library/intro-to-des...
# 6   https://teamtreehouse.com/library/conducting-u...
# 7   https://teamtreehouse.com/library/data-analysi...
# 8   https://teamtreehouse.com/library/spreadsheet-...
# 9   https://teamtreehouse.com/library/web-accessib...
# 10  https://teamtreehouse.com/library/data-visuali...
# 11      https://teamtreehouse.com/library/soft-skills
# 12  https://teamtreehouse.com/library/presentation...
#
#    corporate_sponsor|1|name corporate_sponsor|1|logo corporate_sponsor|2|name  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
# 3                       NaN                      NaN                      NaN
# 4                       NaN                      NaN                      NaN
# 5                       NaN                      NaN                      NaN
# 6                       NaN                      NaN                      NaN
# 7                       NaN                      NaN                      NaN
# 8                       NaN                      NaN                      NaN
# 9                       NaN                      NaN                      NaN
# 10                      NaN                      NaN                      NaN
# 11                      NaN                      NaN                      NaN
# 12                      NaN                      NaN                      NaN
#
#    corporate_sponsor|2|logo accreditation|1|name accreditation|1|logo  \
# 0                       NaN                  NaN                  NaN
# 1                       NaN                  NaN                  NaN
# 2                       NaN                  NaN                  NaN
# 3                       NaN                  NaN                  NaN
# 4                       NaN                  NaN                  NaN
# 5                       NaN                  NaN                  NaN
# 6                       NaN                  NaN                  NaN
# 7                       NaN                  NaN                  NaN
# 8                       NaN                  NaN                  NaN
# 9                       NaN                  NaN                  NaN
# 10                      NaN                  NaN                  NaN
# 11                      NaN                  NaN                  NaN
# 12                      NaN                  NaN                  NaN
#
#    accreditation|1|description accreditation|2|name accreditation|2|logo  \
# 0                          NaN                  NaN                  NaN
# 1                          NaN                  NaN                  NaN
# 2                          NaN                  NaN                  NaN
# 3                          NaN                  NaN                  NaN
# 4                          NaN                  NaN                  NaN
# 5                          NaN                  NaN                  NaN
# 6                          NaN                  NaN                  NaN
# 7                          NaN                  NaN                  NaN
# 8                          NaN                  NaN                  NaN
# 9                          NaN                  NaN                  NaN
# 10                         NaN                  NaN                  NaN
# 11                         NaN                  NaN                  NaN
# 12                         NaN                  NaN                  NaN
#
#    accreditation|2|description assessment_content post_course_interaction  \
# 0                          NaN                NaN                     NaN
# 1                          NaN                NaN                     NaN
# 2                          NaN                NaN                     NaN
# 3                          NaN                NaN                     NaN
# 4                          NaN                NaN                     NaN
# 5                          NaN                NaN                     NaN
# 6                          NaN                NaN                     NaN
# 7                          NaN                NaN                     NaN
# 8                          NaN                NaN                     NaN
# 9                          NaN                NaN                     NaN
# 10                         NaN                NaN                     NaN
# 11                         NaN                NaN                     NaN
# 12                         NaN                NaN                     NaN
#
#    international_faculty human_interaction personalized_teaching live_class  \
# 0                    NaN               NaN                   NaN        NaN
# 1                    NaN               NaN                   NaN        NaN
# 2                    NaN               NaN                   NaN        NaN
# 3                    NaN               NaN                   NaN        NaN
# 4                    NaN               NaN                   NaN        NaN
# 5                    NaN               NaN                   NaN        NaN
# 6                    NaN               NaN                   NaN        NaN
# 7                    NaN               NaN                   NaN        NaN
# 8                    NaN               NaN                   NaN        NaN
# 9                    NaN               NaN                   NaN        NaN
# 10                   NaN               NaN                   NaN        NaN
# 11                   NaN               NaN                   NaN        NaN
# 12                   NaN               NaN                   NaN        NaN
#
#    job_assistance internship alumni_network placement|1|company_name  \
# 0             NaN        NaN            NaN                      NaN
# 1             NaN        NaN            NaN                      NaN
# 2             NaN        NaN            NaN                      NaN
# 3             NaN        NaN            NaN                      NaN
# 4             NaN        NaN            NaN                      NaN
# 5             NaN        NaN            NaN                      NaN
# 6             NaN        NaN            NaN                      NaN
# 7             NaN        NaN            NaN                      NaN
# 8             NaN        NaN            NaN                      NaN
# 9             NaN        NaN            NaN                      NaN
# 10            NaN        NaN            NaN                      NaN
# 11            NaN        NaN            NaN                      NaN
# 12            NaN        NaN            NaN                      NaN
#
#    placement|1|role_offered placement|2|company_name placement|2|role_offered  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
# 3                       NaN                      NaN                      NaN
# 4                       NaN                      NaN                      NaN
# 5                       NaN                      NaN                      NaN
# 6                       NaN                      NaN                      NaN
# 7                       NaN                      NaN                      NaN
# 8                       NaN                      NaN                      NaN
# 9                       NaN                      NaN                      NaN
# 10                      NaN                      NaN                      NaN
# 11                      NaN                      NaN                      NaN
# 12                      NaN                      NaN                      NaN
#
#    learning_mediums virtual_labs case_based_learning capstone_project  \
# 0               NaN          NaN                 NaN              NaN
# 1               NaN          NaN                 NaN              NaN
# 2               NaN          NaN                 NaN              NaN
# 3               NaN          NaN                 NaN              NaN
# 4               NaN          NaN                 NaN              NaN
# 5               NaN          NaN                 NaN              NaN
# 6               NaN          NaN                 NaN              NaN
# 7               NaN          NaN                 NaN              NaN
# 8               NaN          NaN                 NaN              NaN
# 9               NaN          NaN                 NaN              NaN
# 10              NaN          NaN                 NaN              NaN
# 11              NaN          NaN                 NaN              NaN
# 12              NaN          NaN                 NaN              NaN
#
#    average_salary highest_salary application_seat_ratio bounce_rate  \
# 0             NaN            NaN                    NaN         NaN
# 1             NaN            NaN                    NaN         NaN
# 2             NaN            NaN                    NaN         NaN
# 3             NaN            NaN                    NaN         NaN
# 4             NaN            NaN                    NaN         NaN
# 5             NaN            NaN                    NaN         NaN
# 6             NaN            NaN                    NaN         NaN
# 7             NaN            NaN                    NaN         NaN
# 8             NaN            NaN                    NaN         NaN
# 9             NaN            NaN                    NaN         NaN
# 10            NaN            NaN                    NaN         NaN
# 11            NaN            NaN                    NaN         NaN
# 12            NaN            NaN                    NaN         NaN
#
#    completion_ratio enrollment_ratio faculty_student_ratio gender_diversity  \
# 0               NaN              NaN                   NaN              NaN
# 1               NaN              NaN                   NaN              NaN
# 2               NaN              NaN                   NaN              NaN
# 3               NaN              NaN                   NaN              NaN
# 4               NaN              NaN                   NaN              NaN
# 5               NaN              NaN                   NaN              NaN
# 6               NaN              NaN                   NaN              NaN
# 7               NaN              NaN                   NaN              NaN
# 8               NaN              NaN                   NaN              NaN
# 9               NaN              NaN                   NaN              NaN
# 10              NaN              NaN                   NaN              NaN
# 11              NaN              NaN                   NaN              NaN
# 12              NaN              NaN                   NaN              NaN
#
#    student_stream_diversity student_nationality_diversity average_salary_hike  \
# 0                       NaN                           NaN                 NaN
# 1                       NaN                           NaN                 NaN
# 2                       NaN                           NaN                 NaN
# 3                       NaN                           NaN                 NaN
# 4                       NaN                           NaN                 NaN
# 5                       NaN                           NaN                 NaN
# 6                       NaN                           NaN                 NaN
# 7                       NaN                           NaN                 NaN
# 8                       NaN                           NaN                 NaN
# 9                       NaN                           NaN                 NaN
# 10                      NaN                           NaN                 NaN
# 11                      NaN                           NaN                 NaN
# 12                      NaN                           NaN                 NaN
#
#    instructor_citations syllabus
# 0                   NaN      NaN
# 1                   NaN      NaN
# 2                   NaN      NaN
# 3                   NaN      NaN
# 4                   NaN      NaN
# 5                   NaN      NaN
# 6                   NaN      NaN
# 7                   NaN      NaN
# 8                   NaN      NaN
# 9                   NaN      NaN
# 10                  NaN      NaN
# 11                  NaN      NaN
# 12                  NaN      NaN

# %%
op_df.to_excel("Product_management_Basics.xlsx")
