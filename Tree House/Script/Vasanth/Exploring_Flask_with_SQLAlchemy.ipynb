# %%
import pandas as pd
from bs4 import BeautifulSoup
from bs4.element import Comment
import requests
import urllib.request
import cssutils
import re
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import time

# %%
pd.set_option("display.max_columns", 156)

# %%
driver=webdriver.Chrome(r"C:\ProgramData\chocolatey\bin\chromedriver")

# %%
op_df=pd.DataFrame(pd.read_csv("output.csv"))

# %%
op_df
# Out:
# Empty DataFrame
# Columns: [title, learn_type, topics, skills, description, cover_image, cover_video, embedded_video_url, delivery_method, instruction_type, content, what_will_learn, prerequisites, target_students, instructor|1|name, instructor|1|designation, instructor|1|instructor_bio, instructor|1|linkedin_url, instructor|1|facebook_url, instructor|1|twitter_url, instructor|1|instructor_image, instructor|2|name, instructor|2|designation, instructor|2|instructor_bio, instructor|2|linkedin_url, instructor|2|facebook_url, instructor|2|twitter_url, instructor|2|instructor_image, instructor|3|name, instructor|3|designation, instructor|3|instructor_bio, instructor|3|linkedin_url, instructor|3|facebook_url, instructor|3|twitter_url, instructor|3|instructor_image, instructor|4|name, instructor|4|designation, instructor|4|instructor_bio, instructor|4|linkedin_url, instructor|4|facebook_url, instructor|4|twitter_url, instructor|4|instructor_image, instructor|5|name, instructor|5|designation, instructor|5|instructor_bio, instructor|5|linkedin_url, instructor|5|facebook_url, instructor|5|twitter_url, instructor|5|instructor_image, review|1|reviewer_name, review|1|photo, review|1|review_date, review|1|review, review|1|rating, review|2|reviewer_name, review|2|photo, review|2|review_date, review|2|review, review|2|rating, review|3|reviewer_name, review|3|photo, review|3|review_date, review|3|review, review|3|rating, review|4|reviewer_name, review|4|photo, review|4|review_date, review|4|review, review|5|reviewer_name, review|5|photo, review|5|review_date, review|5|review, review|5|rating, review|5|rating.1, total_duration, total_duration_unit, total_video_content, total_video_content_unit, recommended_effort_per_week, avg_session_duration_with_instructor, batch|1|batch_size, batch|1|batch_start_date, batch|1|batch_end_date, batch|2|batch_size, batch|2|batch_start_date, batch|2|batch_end_date, enrollment_start_date, enrollment_end_date, level, languages, short_description, subtitle_languages, accessibilities, availabilities, Display Price, pricing_type, currency, regular_price, sale_price, additional_pricing_details, ...]
# Index: []

# %%
urls=["https://teamtreehouse.com/library/introducing-tuples","https://teamtreehouse.com/library/python-sequences","https://teamtreehouse.com/library/introducing-dictionaries","https://teamtreehouse.com/library/functions-packing-and-unpacking","https://teamtreehouse.com/library/sql-basics","https://teamtreehouse.com/library/introduction-to-git","https://teamtreehouse.com/library/sqlalchemy-basics","https://teamtreehouse.com/library/introduction-to-html-and-css","https://teamtreehouse.com/library/flask-with-sqlalchemy-basics"]

# %%
html_content=[]
soup=[]

for i in range (len(urls)):
    html_content.append(requests.get(urls[i]).text)
    soup.append(BeautifulSoup(html_content[i], "lxml"))

# %%
title=[]
for i in soup:
    title.append(i.title.text)
op_df["title"]=title

# %%
description=[]
for i in soup:
    try:
        pt=(i.find(class_="grid-66 tablet-grid-60").find_all("p"))
        description.append(pt[1])
    except:
        print("Error")
op_df["description"]=description

# %%
inst_1_name=[]
for i in soup:
    try:
        inst_1_name.append(i.find("div",{"id" : "syllabus-authors"}).find("h4").text)
    except:
        inst_1_name.append(i.find("div",{"id" : "workshop-authors"}).find("h4").text)
op_df["instructor|1|name"]=inst_1_name

# %%
inst_bio=[]
for i in soup:
    inst_bio.append(i.find(class_="grid-33 tablet-grid-40").find("p").text)
op_df["instructor|1|instructor_bio"]=inst_bio

# %%
inst_desig=[]
for i in soup:
    inst_desig.append("Teacher")
op_df["instructor|1|designation"]=inst_desig

# %%
inst_img=[]
for i in soup:
    prt=(i.find(class_="instructor-avatar")["style"].split("("))
    inst_img.append(prt[1].replace(")",""))
op_df["instructor|1|instructor_image"]=inst_img

# %%
level=[]
for i in soup:
    try:
        level.append(i.find("li",{"id" : "syllabus-skill-level"}).text)
    except:
        level.append(i.find("li",{"id" : "workshop-skill-level"}).text)
op_df["level"]=level

# %%
topics=[]
for i in soup:
        topics.append(i.find("ul",class_="tags actions").find("a").text)            
op_df["topics"]=topics

# %%
op_df["partner_course_url"]=urls

# %%
what_will_learn=[]
for i in soup:
    try:
        what_will_learn.append(i.find(class_="check-list").text.replace("\n","|"))
        
    except:
        what_will_learn.append(i.find(class_="check-list"))
op_df["what_will_learn"]=what_will_learn

# %%
learn_type=[]
for i in soup:
    if(i.text.find("Workshop"))>=1:
        learn_type.append("Workshop")
    else:
        learn_type.append("Course")
op_df["learn_type"]=learn_type

# %%
duration=[]
duration_unit=[]
for i in soup:
    try:
        pt=(i.find("div",{"id" : "syllabus-title"}).find("h2").text.replace("\n","").split(" "))
        pt=(pt[4].split("-"))
        duration.append(pt[0])
        duration_unit.append(pt[1])
    except:
        pr=(i.find("div",{"id" : "workshop-title"}).find("h2").text.replace("\n","").split(" "))
        pr=(pr[4].split("-"))
        duration.append(pr[0])
        duration_unit.append(pr[1])
                
op_df["total_duration"]=duration
op_df["total_duration_unit"]=duration_unit

# %%
lang=[]
for i in soup:
    lang.append("English")
op_df["languages"]=lang
op_df["subtitle_languages"]=lang

# %%
inst_type=[]
for i in soup:
    inst_type.append("Self Paced")
op_df["instruction_type"]=inst_type

# %%
available=[]
for i in soup:
    available.append("Downloadable Content")
op_df["availabilities"]=available

# %%
content=[]
for i in urls:
    tempro=[]
    driver.get(i)
    time.sleep(5)
    a=driver.find_elements_by_class_name("toggle-steps")
    for i in a:
        time.sleep(2)
        try:
            i.click()
        except:
            pass
    pri=(driver.find_elements_by_class_name("stage-meta"))
    for j in pri:
        prnt=(j.text.replace(":","").replace("questions","").replace("\n","|"))
        res = ''.join([i for i in prnt if not i.isdigit()])
        tempro.append(res)
    content.append(tempro)



op_df["content"]=content

# %%
op_df #17 Kpis (Excluding Content)
# Out:
#                                                title learn_type  \
# 0     Introducing Tuples Course (How To) | Treehouse     Course
# 1       Python Sequences Course (How To) | Treehouse     Course
# 2  Introducing Dictionaries Course (How To) | Tre...     Course
# 3  Functions, Packing,  and Unpacking Course (How...     Course
# 4             SQL Basics Course (How To) | Treehouse     Course
# 5    Introduction to Git Course (How To) | Treehouse     Course
# 6      SQLAlchemy Basics Course (How To) | Treehouse     Course
# 7          Learn HTML and CSS with Our Video Lessons     Course
# 8  Flask with SQLAlchemy Basics Course (How To) |...     Course
#
#               topics skills  \
# 0             Python    NaN
# 1             Python    NaN
# 2             Python    NaN
# 3             Python    NaN
# 4          Databases    NaN
# 5  Development Tools    NaN
# 6             Python    NaN
# 7               HTML    NaN
# 8             Python    NaN
#
#                                          description cover_image cover_video  \
# 0  [Learn about a python data structures that's s...         NaN         NaN
# 1  [Discover several types of Python sequences, m...         NaN         NaN
# 2  [Another useful Python data structure is the d...         NaN         NaN
# 3  [Learn the ins and outs of Python functions, h...         NaN         NaN
# 4  [In SQL Basics we’ll take a look at what datab...         NaN         NaN
# 5  [Git is a version control system - it helps yo...         NaN         NaN
# 6  [Creating a SQL database including model creat...         NaN         NaN
# 7  [Get started creating web pages with HTML and ...         NaN         NaN
# 8  [Learn how to use the popular Python framework...         NaN         NaN
#
#   embedded_video_url delivery_method instruction_type  \
# 0                NaN             NaN       Self Paced
# 1                NaN             NaN       Self Paced
# 2                NaN             NaN       Self Paced
# 3                NaN             NaN       Self Paced
# 4                NaN             NaN       Self Paced
# 5                NaN             NaN       Self Paced
# 6                NaN             NaN       Self Paced
# 7                NaN             NaN       Self Paced
# 8                NaN             NaN       Self Paced
#
#                                              content  \
# 0  [Getting to Know Tuples|Learn the difference b...
# 1  [Sequence Iteration|Learn  different ways to i...
# 2  [Introducing Dictionaries|Discover an unfamili...
# 3  [Introduction to Functions|Discover the basics...
# 4  [Data, Databases and SQL|We'll take a look at ...
# 5  [First Commits|We'll show you what Git reposit...
# 6  [Introduction to SQLAlchemy|Learn about SQLAlc...
# 7  [Getting Familiar with HTML and CSS|Learn the ...
# 8  [Creating a Basic Website with Flask|Use Pytho...
#
#                                      what_will_learn prerequisites  \
# 0                                           |Tuples|           NaN
# 1     |For loops|Slicing|Ranges|Sequence operations|           NaN
# 2    |**kwargs|Writing dictionaries|Key:value pairs|           NaN
# 3  |Function definition|Arguments and parameters|...           NaN
# 4  |Write SELECT statement to query data from a r...           NaN
# 5              |Repositories|Commits|History|GitHub|           NaN
# 6  |Create a database model|Interact with a datab...           NaN
# 7  |Define HTML and CSS|Add and change HTML tags|...           NaN
# 8  |Creating a website or web app with Flask|Conn...           NaN
#
#   target_students instructor|1|name instructor|1|designation  \
# 0             NaN    Ashley Boucher                  Teacher
# 1             NaN    Ashley Boucher                  Teacher
# 2             NaN    Ashley Boucher                  Teacher
# 3             NaN    Ashley Boucher                  Teacher
# 4             NaN   Andrew Chalkley                  Teacher
# 5             NaN      Jay McGavren                  Teacher
# 6             NaN    Megan Amendola                  Teacher
# 7             NaN    Treasure Porth                  Teacher
# 8             NaN    Megan Amendola                  Teacher
#
#                          instructor|1|instructor_bio  \
# 0  I'm a Portland resident who loves building in ...
# 1  I'm a Portland resident who loves building in ...
# 2  I'm a Portland resident who loves building in ...
# 3  I'm a Portland resident who loves building in ...
# 4  I'm an alien, I'm a legal alien, I'm an Englis...
# 5  Resident Ruby and Go teacher for Treehouse. Au...
# 6  Megan is an instructor knowledgeable in a few ...
# 7  Web developer, JavaScript enthusiast, educatio...
# 8  Megan is an instructor knowledgeable in a few ...
#
#   instructor|1|linkedin_url instructor|1|facebook_url  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
#
#   instructor|1|twitter_url                      instructor|1|instructor_image  \
# 0                      NaN  'https://uploads.teamtreehouse.com/production/...
# 1                      NaN  'https://uploads.teamtreehouse.com/production/...
# 2                      NaN  'https://uploads.teamtreehouse.com/production/...
# 3                      NaN  'https://uploads.teamtreehouse.com/production/...
# 4                      NaN  'https://uploads.teamtreehouse.com/production/...
# 5                      NaN  'https://uploads.teamtreehouse.com/production/...
# 6                      NaN  'https://uploads.teamtreehouse.com/production/...
# 7                      NaN  'https://uploads.teamtreehouse.com/production/...
# 8                      NaN  'https://uploads.teamtreehouse.com/production/...
#
#   instructor|2|name instructor|2|designation instructor|2|instructor_bio  \
# 0               NaN                      NaN                         NaN
# 1               NaN                      NaN                         NaN
# 2               NaN                      NaN                         NaN
# 3               NaN                      NaN                         NaN
# 4               NaN                      NaN                         NaN
# 5               NaN                      NaN                         NaN
# 6               NaN                      NaN                         NaN
# 7               NaN                      NaN                         NaN
# 8               NaN                      NaN                         NaN
#
#   instructor|2|linkedin_url instructor|2|facebook_url  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
#
#   instructor|2|twitter_url instructor|2|instructor_image instructor|3|name  \
# 0                      NaN                           NaN               NaN
# 1                      NaN                           NaN               NaN
# 2                      NaN                           NaN               NaN
# 3                      NaN                           NaN               NaN
# 4                      NaN                           NaN               NaN
# 5                      NaN                           NaN               NaN
# 6                      NaN                           NaN               NaN
# 7                      NaN                           NaN               NaN
# 8                      NaN                           NaN               NaN
#
#   instructor|3|designation instructor|3|instructor_bio  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
# 5                      NaN                         NaN
# 6                      NaN                         NaN
# 7                      NaN                         NaN
# 8                      NaN                         NaN
#
#   instructor|3|linkedin_url instructor|3|facebook_url  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
#
#   instructor|3|twitter_url instructor|3|instructor_image instructor|4|name  \
# 0                      NaN                           NaN               NaN
# 1                      NaN                           NaN               NaN
# 2                      NaN                           NaN               NaN
# 3                      NaN                           NaN               NaN
# 4                      NaN                           NaN               NaN
# 5                      NaN                           NaN               NaN
# 6                      NaN                           NaN               NaN
# 7                      NaN                           NaN               NaN
# 8                      NaN                           NaN               NaN
#
#   instructor|4|designation instructor|4|instructor_bio  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
# 5                      NaN                         NaN
# 6                      NaN                         NaN
# 7                      NaN                         NaN
# 8                      NaN                         NaN
#
#   instructor|4|linkedin_url instructor|4|facebook_url  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
#
#   instructor|4|twitter_url instructor|4|instructor_image instructor|5|name  \
# 0                      NaN                           NaN               NaN
# 1                      NaN                           NaN               NaN
# 2                      NaN                           NaN               NaN
# 3                      NaN                           NaN               NaN
# 4                      NaN                           NaN               NaN
# 5                      NaN                           NaN               NaN
# 6                      NaN                           NaN               NaN
# 7                      NaN                           NaN               NaN
# 8                      NaN                           NaN               NaN
#
#   instructor|5|designation instructor|5|instructor_bio  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
# 5                      NaN                         NaN
# 6                      NaN                         NaN
# 7                      NaN                         NaN
# 8                      NaN                         NaN
#
#   instructor|5|linkedin_url instructor|5|facebook_url  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
#
#   instructor|5|twitter_url instructor|5|instructor_image  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
# 2                      NaN                           NaN
# 3                      NaN                           NaN
# 4                      NaN                           NaN
# 5                      NaN                           NaN
# 6                      NaN                           NaN
# 7                      NaN                           NaN
# 8                      NaN                           NaN
#
#   review|1|reviewer_name review|1|photo review|1|review_date review|1|review  \
# 0                    NaN            NaN                  NaN             NaN
# 1                    NaN            NaN                  NaN             NaN
# 2                    NaN            NaN                  NaN             NaN
# 3                    NaN            NaN                  NaN             NaN
# 4                    NaN            NaN                  NaN             NaN
# 5                    NaN            NaN                  NaN             NaN
# 6                    NaN            NaN                  NaN             NaN
# 7                    NaN            NaN                  NaN             NaN
# 8                    NaN            NaN                  NaN             NaN
#
#   review|1|rating review|2|reviewer_name review|2|photo review|2|review_date  \
# 0             NaN                    NaN            NaN                  NaN
# 1             NaN                    NaN            NaN                  NaN
# 2             NaN                    NaN            NaN                  NaN
# 3             NaN                    NaN            NaN                  NaN
# 4             NaN                    NaN            NaN                  NaN
# 5             NaN                    NaN            NaN                  NaN
# 6             NaN                    NaN            NaN                  NaN
# 7             NaN                    NaN            NaN                  NaN
# 8             NaN                    NaN            NaN                  NaN
#
#   review|2|review review|2|rating review|3|reviewer_name review|3|photo  \
# 0             NaN             NaN                    NaN            NaN
# 1             NaN             NaN                    NaN            NaN
# 2             NaN             NaN                    NaN            NaN
# 3             NaN             NaN                    NaN            NaN
# 4             NaN             NaN                    NaN            NaN
# 5             NaN             NaN                    NaN            NaN
# 6             NaN             NaN                    NaN            NaN
# 7             NaN             NaN                    NaN            NaN
# 8             NaN             NaN                    NaN            NaN
#
#   review|3|review_date review|3|review review|3|rating review|4|reviewer_name  \
# 0                  NaN             NaN             NaN                    NaN
# 1                  NaN             NaN             NaN                    NaN
# 2                  NaN             NaN             NaN                    NaN
# 3                  NaN             NaN             NaN                    NaN
# 4                  NaN             NaN             NaN                    NaN
# 5                  NaN             NaN             NaN                    NaN
# 6                  NaN             NaN             NaN                    NaN
# 7                  NaN             NaN             NaN                    NaN
# 8                  NaN             NaN             NaN                    NaN
#
#   review|4|photo review|4|review_date review|4|review review|5|reviewer_name  \
# 0            NaN                  NaN             NaN                    NaN
# 1            NaN                  NaN             NaN                    NaN
# 2            NaN                  NaN             NaN                    NaN
# 3            NaN                  NaN             NaN                    NaN
# 4            NaN                  NaN             NaN                    NaN
# 5            NaN                  NaN             NaN                    NaN
# 6            NaN                  NaN             NaN                    NaN
# 7            NaN                  NaN             NaN                    NaN
# 8            NaN                  NaN             NaN                    NaN
#
#   review|5|photo review|5|review_date review|5|review review|5|rating  \
# 0            NaN                  NaN             NaN             NaN
# 1            NaN                  NaN             NaN             NaN
# 2            NaN                  NaN             NaN             NaN
# 3            NaN                  NaN             NaN             NaN
# 4            NaN                  NaN             NaN             NaN
# 5            NaN                  NaN             NaN             NaN
# 6            NaN                  NaN             NaN             NaN
# 7            NaN                  NaN             NaN             NaN
# 8            NaN                  NaN             NaN             NaN
#
#   review|5|rating.1 total_duration total_duration_unit total_video_content  \
# 0               NaN             13              minute                 NaN
# 1               NaN             65              minute                 NaN
# 2               NaN             36              minute                 NaN
# 3               NaN             65              minute                 NaN
# 4               NaN            172              minute                 NaN
# 5               NaN            186              minute                 NaN
# 6               NaN            190              minute                 NaN
# 7               NaN            134              minute                 NaN
# 8               NaN            147              minute                 NaN
#
#   total_video_content_unit recommended_effort_per_week  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
# 5                      NaN                         NaN
# 6                      NaN                         NaN
# 7                      NaN                         NaN
# 8                      NaN                         NaN
#
#   avg_session_duration_with_instructor batch|1|batch_size  \
# 0                                  NaN                NaN
# 1                                  NaN                NaN
# 2                                  NaN                NaN
# 3                                  NaN                NaN
# 4                                  NaN                NaN
# 5                                  NaN                NaN
# 6                                  NaN                NaN
# 7                                  NaN                NaN
# 8                                  NaN                NaN
#
#   batch|1|batch_start_date batch|1|batch_end_date batch|2|batch_size  \
# 0                      NaN                    NaN                NaN
# 1                      NaN                    NaN                NaN
# 2                      NaN                    NaN                NaN
# 3                      NaN                    NaN                NaN
# 4                      NaN                    NaN                NaN
# 5                      NaN                    NaN                NaN
# 6                      NaN                    NaN                NaN
# 7                      NaN                    NaN                NaN
# 8                      NaN                    NaN                NaN
#
#   batch|2|batch_start_date batch|2|batch_end_date enrollment_start_date  \
# 0                      NaN                    NaN                   NaN
# 1                      NaN                    NaN                   NaN
# 2                      NaN                    NaN                   NaN
# 3                      NaN                    NaN                   NaN
# 4                      NaN                    NaN                   NaN
# 5                      NaN                    NaN                   NaN
# 6                      NaN                    NaN                   NaN
# 7                      NaN                    NaN                   NaN
# 8                      NaN                    NaN                   NaN
#
#   enrollment_end_date         level languages short_description  \
# 0                 NaN      Beginner   English               NaN
# 1                 NaN      Beginner   English               NaN
# 2                 NaN      Beginner   English               NaN
# 3                 NaN      Beginner   English               NaN
# 4                 NaN      Beginner   English               NaN
# 5                 NaN      Beginner   English               NaN
# 6                 NaN  Intermediate   English               NaN
# 7                 NaN      Beginner   English               NaN
# 8                 NaN  Intermediate   English               NaN
#
#   subtitle_languages accessibilities        availabilities Display Price  \
# 0            English             NaN  Downloadable Content           NaN
# 1            English             NaN  Downloadable Content           NaN
# 2            English             NaN  Downloadable Content           NaN
# 3            English             NaN  Downloadable Content           NaN
# 4            English             NaN  Downloadable Content           NaN
# 5            English             NaN  Downloadable Content           NaN
# 6            English             NaN  Downloadable Content           NaN
# 7            English             NaN  Downloadable Content           NaN
# 8            English             NaN  Downloadable Content           NaN
#
#   pricing_type currency regular_price sale_price additional_pricing_details  \
# 0          NaN      NaN           NaN        NaN                        NaN
# 1          NaN      NaN           NaN        NaN                        NaN
# 2          NaN      NaN           NaN        NaN                        NaN
# 3          NaN      NaN           NaN        NaN                        NaN
# 4          NaN      NaN           NaN        NaN                        NaN
# 5          NaN      NaN           NaN        NaN                        NaN
# 6          NaN      NaN           NaN        NaN                        NaN
# 7          NaN      NaN           NaN        NaN                        NaN
# 8          NaN      NaN           NaN        NaN                        NaN
#
#   course_financing_available indian_students_program_fee  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# 5                        NaN                         NaN
# 6                        NaN                         NaN
# 7                        NaN                         NaN
# 8                        NaN                         NaN
#
#   indian_students_payment_deadline indian_students_GST_included  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# 5                              NaN                          NaN
# 6                              NaN                          NaN
# 7                              NaN                          NaN
# 8                              NaN                          NaN
#
#   indian_student_installments|1|installment_amount  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
#
#   indian_student_installments|1|payment_deadline  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
#
#   indian_student_installments|2|installment_amount  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
#
#   indian_student_installments|2|payment_deadline  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
#
#   international_students_program_fee international_students_payment_deadline  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
# 5                                NaN                                     NaN
# 6                                NaN                                     NaN
# 7                                NaN                                     NaN
# 8                                NaN                                     NaN
#
#   international_student_installments|1|installment_amount  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
#
#   international_student_installments|1|payment_deadline  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
#
#   international_student_installments|2|installment_amount  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
#
#   international_student_installments|2|payment_deadline institute  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
# 5                                                NaN          NaN
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8                                                NaN          NaN
#
#                                   partner_course_url corporate_sponsor|1|name  \
# 0  https://teamtreehouse.com/library/introducing-...                      NaN
# 1  https://teamtreehouse.com/library/python-seque...                      NaN
# 2  https://teamtreehouse.com/library/introducing-...                      NaN
# 3  https://teamtreehouse.com/library/functions-pa...                      NaN
# 4       https://teamtreehouse.com/library/sql-basics                      NaN
# 5  https://teamtreehouse.com/library/introduction...                      NaN
# 6  https://teamtreehouse.com/library/sqlalchemy-b...                      NaN
# 7  https://teamtreehouse.com/library/introduction...                      NaN
# 8  https://teamtreehouse.com/library/flask-with-s...                      NaN
#
#   corporate_sponsor|1|logo corporate_sponsor|2|name corporate_sponsor|2|logo  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
# 5                      NaN                      NaN                      NaN
# 6                      NaN                      NaN                      NaN
# 7                      NaN                      NaN                      NaN
# 8                      NaN                      NaN                      NaN
#
#   accreditation|1|name accreditation|1|logo accreditation|1|description  \
# 0                  NaN                  NaN                         NaN
# 1                  NaN                  NaN                         NaN
# 2                  NaN                  NaN                         NaN
# 3                  NaN                  NaN                         NaN
# 4                  NaN                  NaN                         NaN
# 5                  NaN                  NaN                         NaN
# 6                  NaN                  NaN                         NaN
# 7                  NaN                  NaN                         NaN
# 8                  NaN                  NaN                         NaN
#
#   accreditation|2|name accreditation|2|logo accreditation|2|description  \
# 0                  NaN                  NaN                         NaN
# 1                  NaN                  NaN                         NaN
# 2                  NaN                  NaN                         NaN
# 3                  NaN                  NaN                         NaN
# 4                  NaN                  NaN                         NaN
# 5                  NaN                  NaN                         NaN
# 6                  NaN                  NaN                         NaN
# 7                  NaN                  NaN                         NaN
# 8                  NaN                  NaN                         NaN
#
#   assessment_content post_course_interaction international_faculty  \
# 0                NaN                     NaN                   NaN
# 1                NaN                     NaN                   NaN
# 2                NaN                     NaN                   NaN
# 3                NaN                     NaN                   NaN
# 4                NaN                     NaN                   NaN
# 5                NaN                     NaN                   NaN
# 6                NaN                     NaN                   NaN
# 7                NaN                     NaN                   NaN
# 8                NaN                     NaN                   NaN
#
#   human_interaction personalized_teaching live_class job_assistance  \
# 0               NaN                   NaN        NaN            NaN
# 1               NaN                   NaN        NaN            NaN
# 2               NaN                   NaN        NaN            NaN
# 3               NaN                   NaN        NaN            NaN
# 4               NaN                   NaN        NaN            NaN
# 5               NaN                   NaN        NaN            NaN
# 6               NaN                   NaN        NaN            NaN
# 7               NaN                   NaN        NaN            NaN
# 8               NaN                   NaN        NaN            NaN
#
#   internship alumni_network placement|1|company_name placement|1|role_offered  \
# 0        NaN            NaN                      NaN                      NaN
# 1        NaN            NaN                      NaN                      NaN
# 2        NaN            NaN                      NaN                      NaN
# 3        NaN            NaN                      NaN                      NaN
# 4        NaN            NaN                      NaN                      NaN
# 5        NaN            NaN                      NaN                      NaN
# 6        NaN            NaN                      NaN                      NaN
# 7        NaN            NaN                      NaN                      NaN
# 8        NaN            NaN                      NaN                      NaN
#
#   placement|2|company_name placement|2|role_offered learning_mediums  \
# 0                      NaN                      NaN              NaN
# 1                      NaN                      NaN              NaN
# 2                      NaN                      NaN              NaN
# 3                      NaN                      NaN              NaN
# 4                      NaN                      NaN              NaN
# 5                      NaN                      NaN              NaN
# 6                      NaN                      NaN              NaN
# 7                      NaN                      NaN              NaN
# 8                      NaN                      NaN              NaN
#
#   virtual_labs case_based_learning capstone_project average_salary  \
# 0          NaN                 NaN              NaN            NaN
# 1          NaN                 NaN              NaN            NaN
# 2          NaN                 NaN              NaN            NaN
# 3          NaN                 NaN              NaN            NaN
# 4          NaN                 NaN              NaN            NaN
# 5          NaN                 NaN              NaN            NaN
# 6          NaN                 NaN              NaN            NaN
# 7          NaN                 NaN              NaN            NaN
# 8          NaN                 NaN              NaN            NaN
#
#   highest_salary application_seat_ratio bounce_rate completion_ratio  \
# 0            NaN                    NaN         NaN              NaN
# 1            NaN                    NaN         NaN              NaN
# 2            NaN                    NaN         NaN              NaN
# 3            NaN                    NaN         NaN              NaN
# 4            NaN                    NaN         NaN              NaN
# 5            NaN                    NaN         NaN              NaN
# 6            NaN                    NaN         NaN              NaN
# 7            NaN                    NaN         NaN              NaN
# 8            NaN                    NaN         NaN              NaN
#
#   enrollment_ratio faculty_student_ratio gender_diversity  \
# 0              NaN                   NaN              NaN
# 1              NaN                   NaN              NaN
# 2              NaN                   NaN              NaN
# 3              NaN                   NaN              NaN
# 4              NaN                   NaN              NaN
# 5              NaN                   NaN              NaN
# 6              NaN                   NaN              NaN
# 7              NaN                   NaN              NaN
# 8              NaN                   NaN              NaN
#
#   student_stream_diversity student_nationality_diversity average_salary_hike  \
# 0                      NaN                           NaN                 NaN
# 1                      NaN                           NaN                 NaN
# 2                      NaN                           NaN                 NaN
# 3                      NaN                           NaN                 NaN
# 4                      NaN                           NaN                 NaN
# 5                      NaN                           NaN                 NaN
# 6                      NaN                           NaN                 NaN
# 7                      NaN                           NaN                 NaN
# 8                      NaN                           NaN                 NaN
#
#   instructor_citations syllabus
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# 5                  NaN      NaN
# 6                  NaN      NaN
# 7                  NaN      NaN
# 8                  NaN      NaN

# %%
op_df.to_excel("Exploring_Flask_with_SQLAlchemy.xlsx")
